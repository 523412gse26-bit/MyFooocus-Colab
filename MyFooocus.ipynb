# %% [markdown]
# <a href="https://colab.research.google.com/github/523412gse26-bit/MyFooocus-Colab/blob/main/MyFooocus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip uninstall -y cupy-cuda12x cupy
# !pip install numpy==1.26.4 cupy-cuda12x==13.3.0 pygit2==1.15.1

# %cd /content
# !rm -rf /content/Fooocus
# !git clone https://github.com/lllyasviel/Fooocus.git

# %cd /content/Fooocus

# !echo "" >> requirements_versions.txt
# !echo "fastapi==0.104.1" >> requirements_versions.txt
# !echo "starlette==0.27.0" >> requirements_versions.txt
# !echo "pydantic==1.10.19" >> requirements_versions.txt

# Start Fooocus
# !python entry_with_update.py --share --always-high-vram --all-in-fp16 --listen
# Out:
# WARNING: Skipping cupy-cuda12x as it is not installed.
# WARNING: Skipping cupy as it is not installed.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.8/15.8 MB 68.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
